# %% [markdown]
# <a href="https://colab.research.google.com/github/GC34ever/CapstoneGC/blob/master/Pythonpractice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello, George! This is the start of your Python journey. Good Luck.") # This message will be caLLed when the browser is executed.
print("Hello, World") # The string will be printed to console when Python is executed. It will display the message (Hello, World).
x = 10000 #The variable x is given the value of (10000)
name = "George"
print(x) # The value of "x" will be printed in the terminal.
print(name)  #The value of "name" will be printed in the terminal.

#Data Types in Python. 7 basic
#int = type of data that is a whole number like (1,3,4,5, etc).
#bool = True/False
#str = string e.g("George, Clark")
#list = ordered collection([0, 1, 2])
#dict = key value pairs ({"name": George})
#variable is a reusable container for storing a value.

age = 26 #the variable age is assigned the value "26".
print(age) # the variable age will print in the terminal.
print(" George You are " + str(age) + " Years old.")# The message will be printed into the console. The message will contain the string "variable" age as well.
print(" George you are",age, "years old.")#This message will be printed in the terminal. It will contain the variable "age".
print(f"You are {age} years old.")#most popular as of now. Therefore the one that will be used the most on my behalf.

players = 535   # number of members in Congress
quantity = 2    # number of chambers in the U.S. government
people = 100    # number of senators
citizens = 435  # number of representatives

print(f"There are {players} members in Congress.")  # print number of members in Congress using f-string

print(f"There are {quantity} chambers in the US government. The Senate has {people} senators, and the other {citizens} are in the House of Representatives.")
# print structure of Congress: chambers, senators, and representatives


isWebDeveloper = True  # indicates whether the person is a web developer

# if statements with python.

if isWebDeveloper:  # execute this block if the person is a web developer
    print("George is a web developer")  # indicate the person is a web developer
else:  # execute this block if the person is NOT a web developer
    print("George is not a web developer")  # indicate the person is not a web developer

print(isWebDeveloper)  # show the value of isWebDeveloper (True or False)

# Dictionaries - collection of key and value pairs. I think of them as like a door and a door and door key.

me = {  # dictionary storing information about George
    "name": "George",          # George's name
    "age": 26,                 # George's age
    "isWebDeveloper": True     # whether George is a web developer or not
}


print(me["name"])  # print George's name

me["age"] = 30     # update George's age to 30
print(me["age"])   # print updated age

del me["isWebDeveloper"]  # remove the web developer status from the dictionary

# you can print these three different ways.

print(me.keys()) # dict_keys(['name', 'age'])
print(me.values()) # dict_values(['George', 30])
print(me.items()) # dict_items([('name', 'George'), ('age', 30)])

def greet(namedPerson):  # define a function that takes a person's name as a parameter
    print(f"Hello, {namedPerson}!")  # code inside the function must be indented

# Call the function multiple times
greet("George")  # greet George
greet("JimiHendrix")    # greet JimiHendrix
greet("NYC")     # greet NYC

message = greet("George")  # store the greeting message returned by the function
print(message)  # Hello, George!

#Operators

#Arithmetic: + - * / % // **
#Comparison: == != > < >= <=
#Logical: and, or, not

#Conditional statement

A = "Apple" # The string is equal to apple

if A == "Pear": # The value of a strong is strictly equal to a pear
    print("Pears are better than apples") # execute this code.
else: # the value is not equal to pear
    print("No fruit is better than an apple.") # execute this code.

A = "Apple"  # The string is equal to Apple

if A == "Pear":  # If the value is Pear, then run this code
    print("Pears are better than apples")  # Output this if it's Pear
elif A == "Banana":  # If the value is Banana, then run this code
    print("Bananas are better than apples")  # Output this if it's Banana
else:
    print("No fruit is better than an apple.")  # Output this instead
# If it’s not Pear or Banana

# List and loops

bros = ["Kobe", "Cody", "Plenty"]  # a list that contains 3 items.

for bro in bros:  # loop through each item in the list
    print(bro)    # print the item in the terminal

bros = ["Kobe", "Cody", "Plenty"]  # same list again

for bro in bros:  # loop through each name
    print(f"Hey, {bro}!")  # greet each of my brothers individually

#Input statement Here .

dateOfBirth = input("Enter your name: ")  # ask the user for their date of birth

# int()       # change input into a whole number
# float()     # change input into a decimal number
# str()       # make input a string
# bool()      # change input into True or False
# list()      # turn input into a list of items
# tuple()     # turn input into a tuple of items
# set()       # turn input into a set
# complex()   # change input into a complex number
#
birthYear = int(input("Enter your birth year (just numbers here): "))
  # convert input to integer
  # stores a text to give to the user

#import is used to bring collections of code to python for me to use.
#from...import... let me import particular parts of a module instead of the whole thing.

#import module examples

# import math         # math functions like sqrt, sin, cos, etc.
# import random       # generate random numbers, choose random items
# import datetime     # work with dates and times
# import os           # interact with the operating system (files, folders, paths)
# import sys          # access system-specific parameters and functions
# import json         # read and write JSON data
# import re           # regular expressions for pattern matching
# import time         # time-related functions, like sleep


from math import sqrt  # just import sqrt from math
print(sqrt(16))        # now sqrt can be used directly

#-George Clark 8/29/2025

#Project1 starts here.

from datetime import date, datetime  # import date and datetime from the datetime module

dob = input("enter your date of birth (YYYY-MM-DD): ")  # ask user for their date of birth

dob = datetime.strptime(dob, "%Y-%m-%d").date()  # change the string input into a date type

# strptime - string parse time. This will take a variable and convert it into a datetime object.

# "%Y-%m-%d"

# %Y - 4-digit year (e.g., 1997)

# %m - 2-digit month (01–12)

# %d - 2-digit day (01–31)

today = date.today()  # get today's date from the system

age = today.year - dob.year - ((today.month, today.day) < (dob.month, dob.day))# Calculate age: start with year difference, then subtract 1 if today's month/day is before the birthday this year

print(f"you are {age} years old.")  # final output printed in the terminal
# Out:
# Hello, George! This is the start of your Python journey. Good Luck.
# Hello, World
# 10000
# George
# 26
#  George You are 26 Years old.
#  George you are 26 years old.
# You are 26 years old.
# There are 535 members in Congress.
# There are 2 chambers in the US government. The Senate has 100 senators, and the other 435 are in the House of Representatives.
# George is a web developer
# True
# George
# 30
# dict_keys(['name', 'age'])
# dict_values(['George', 30])
# dict_items([('name', 'George'), ('age', 30)])
# Hello, George!
# Hello, JimiHendrix!
# Hello, NYC!
# Hello, George!
# None
# No fruit is better than an apple.
# No fruit is better than an apple.
# Kobe
# Cody
# Plenty
# Hey, Kobe!
# Hey, Cody!
# Hey, Plenty!
# Enter your name: george
# Enter your birth year (just numbers here): 1999
# 4.0
# enter your date of birth (YYYY-MM-DD): 1999-04-26
# you are 26 years old.
